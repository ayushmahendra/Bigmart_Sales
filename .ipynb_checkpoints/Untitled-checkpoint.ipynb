# %% [markdown]
# # Sales Prediction for Big Mart Outlets
#
# The data scientists at BigMart have collected 2013 sales data for 1559 products across 10 stores in different cities. Also, certain attributes of each product and store have been defined. The aim is to build a predictive model and predict the sales of each product at a particular outlet.
#
# Using this model, BigMart will try to understand the properties of products and outlets which play a key role in increasing sales.
#
# Please note that the data may have missing values as some stores might not report all the data due to technical glitches. Hence, it will be required to treat them accordingly.
#
#
# Variable
#
# Item_Identifier-	Unique product ID,
# Item_Weight-        Weight of product,
# Item_Fat_Content-	Whether the product is low fat or not,
# Item_Visibility-	The % of total display area of all products in a store allocated to the particular product,
# Item_Type-	        The category to which the product belongs,
# Item_MRP-	        Maximum Retail Price (list price) of the product,
# Outlet_Identifier-	Unique store ID,
# Outlet_Establishment_Year- The year in which store was established,
# Outlet_Size-	       The size of the store in terms of ground area covered,
# Outlet_Location_Type-  The type of city in which the store is located,
# Outlet_Type-	       Whether the outlet is just a grocery store or some sort of supermarket,
# Item_Outlet_Sales-	   Sales of the product in the particular store. This is the outcome variable to be predicted.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
import warnings
warnings.filterwarnings('ignore')
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

# %%
df=pd.read_csv('train.csv')

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
# Item_Identifier              8523 non-null object
# Item_Weight                  7060 non-null float64
# Item_Fat_Content             8523 non-null object
# Item_Visibility              8523 non-null float64
# Item_Type                    8523 non-null object
# Item_MRP                     8523 non-null float64
# Outlet_Identifier            8523 non-null object
# Outlet_Establishment_Year    8523 non-null int64
# Outlet_Size                  6113 non-null object
# Outlet_Location_Type         8523 non-null object
# Outlet_Type                  8523 non-null object
# Item_Outlet_Sales            8523 non-null float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.1+ KB

# %%
df.describe().T
# Out:
#                             count         mean          std       min  \
# Item_Weight                7060.0    12.857645     4.643456     4.555
# Item_Visibility            8523.0     0.066132     0.051598     0.000
# Item_MRP                   8523.0   140.992782    62.275067    31.290
# Outlet_Establishment_Year  8523.0  1997.831867     8.371760  1985.000
# Item_Outlet_Sales          8523.0  2181.288914  1706.499616    33.290
#
#                                    25%          50%          75%           max
# Item_Weight                   8.773750    12.600000    16.850000     21.350000
# Item_Visibility               0.026989     0.053931     0.094585      0.328391
# Item_MRP                     93.826500   143.012800   185.643700    266.888400
# Outlet_Establishment_Year  1987.000000  1999.000000  2004.000000   2009.000000
# Item_Outlet_Sales           834.247400  1794.331000  3101.296400  13086.964800

# %%
df.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
sns.pairplot(df,diag_kind='kde')

# %% [markdown]
# ## Null Values treatment

# %%
iw=df['Item_Weight'].mean()

# %%
iw
# Out:
# 12.857645184136183

# %%
df['Item_Weight']=df['Item_Weight'].fillna(iw)

# %%
df['Outlet_Size'].mode()
# Out:
# 0    Medium
# dtype: object

# %%
df['Outlet_Size']=df['Outlet_Size'].fillna('Medium')

# %%
df.isnull().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %% [markdown]
# ## Encoding

# %%
df['Item_Fat_Content']=le.fit_transform(df['Item_Fat_Content'])

# %%
df['Item_Type']=le.fit_transform(df['Item_Type'])

# %%
df['Outlet_Identifier']=le.fit_transform(df['Outlet_Identifier'])

# %%
df['Outlet_Size']=le.fit_transform(df['Outlet_Size'])

# %%
df['Outlet_Location_Type']=le.fit_transform(df['Outlet_Location_Type'])

# %%
df['Outlet_Type']=le.fit_transform(df['Outlet_Type'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
# Item_Identifier              8523 non-null object
# Item_Weight                  8523 non-null float64
# Item_Fat_Content             8523 non-null int32
# Item_Visibility              8523 non-null float64
# Item_Type                    8523 non-null int32
# Item_MRP                     8523 non-null float64
# Outlet_Identifier            8523 non-null int32
# Outlet_Establishment_Year    8523 non-null int64
# Outlet_Size                  8523 non-null int32
# Outlet_Location_Type         8523 non-null int32
# Outlet_Type                  8523 non-null int32
# Item_Outlet_Sales            8523 non-null float64
# dtypes: float64(4), int32(6), int64(1), object(1)
# memory usage: 599.4+ KB

# %%
df=df.drop('Item_Identifier', axis=1)

# %%
df.head()
# Out:
#    Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type  Item_MRP  \
# 0         9.30                 1         0.016047          4  249.8092
# 1         5.92                 2         0.019278         14   48.2692
# 2        17.50                 1         0.016760         10  141.6180
# 3        19.20                 2         0.000000          6  182.0950
# 4         8.93                 1         0.000000          9   53.8614
#
#    Outlet_Identifier  Outlet_Establishment_Year  Outlet_Size  \
# 0                  9                       1999            1
# 1                  3                       2009            1
# 2                  9                       1999            1
# 3                  0                       1998            1
# 4                  1                       1987            0
#
#    Outlet_Location_Type  Outlet_Type  Item_Outlet_Sales
# 0                     0            1          3735.1380
# 1                     2            2           443.4228
# ...

# %%
sns.pairplot(df,diag_kind='kde')

# %%
plt.figure(figsize = (24,10))
df.boxplot()    # outliers Checking to see wether outliers are there or not in item _outlet_sales outliers are there but we can't remove outliers from this feature because somepeople can do purchase of more amount

# %%
sns.barplot(x=df['Item_Type'],y=df['Item_Outlet_Sales'])

# %% [markdown]
# So here we can see that item 15 is having hogher outlet sales

# %%
sns.barplot(x=df['Item_Type'],y=df['Item_MRP'])

# %% [markdown]
# Here we can also asee that item 9 is having highest MRP

# %%
sns.barplot(x=df['Item_Type'],y=df['Outlet_Size'])

# %% [markdown]
# here outlet size of 1.25 is more

# %%
sns.scatterplot(x=df['Item_Fat_Content'],y=df['Item_Outlet_Sales'])

# %% [markdown]
# Here we can see that item type of 1 is having highest item outlet sales

# %%
sns.scatterplot(x=df['Outlet_Type'],y=df['Item_Outlet_Sales'])

# %% [markdown]
# Here from oulet type 3 we are getting higher item_outlet_sales

# %%
sns.boxplot(x='Outlet_Size',y='Item_Outlet_Sales', data=df)
plt.show()

# %% [markdown]
# Here outlet size of 1 is having highest sales

# %%
plt.figure(figsize=(8,6))
plt.pie(df['Outlet_Size'].value_counts(),labels=df['Outlet_Size'].unique(),autopct='%1.2f%%')
plt.show()

# %% [markdown]
# Here outlet size of 1 is more purchased by the customers

# %%
plt.figure(figsize=(8,6))
plt.pie(df['Item_Fat_Content'].value_counts(),labels=df['Item_Fat_Content'].unique(),autopct='%1.2f%%')
plt.show()

# %% [markdown]
# Item of Fat_Content 1 is more preffered by the customers and item of fat content 4 is very leass preffered by customers

# %%
X=df.iloc[:,:-1]
y=df.iloc[:,-1]

# %%
X.head()
# Out:
#    Item_Weight  Item_Fat_Content  Item_Visibility  Item_Type  Item_MRP  \
# 0         9.30                 1         0.016047          4  249.8092
# 1         5.92                 2         0.019278         14   48.2692
# 2        17.50                 1         0.016760         10  141.6180
# 3        19.20                 2         0.000000          6  182.0950
# 4         8.93                 1         0.000000          9   53.8614
#
#    Outlet_Identifier  Outlet_Establishment_Year  Outlet_Size  \
# 0                  9                       1999            1
# 1                  3                       2009            1
# 2                  9                       1999            1
# 3                  0                       1998            1
# 4                  1                       1987            0
#
#    Outlet_Location_Type  Outlet_Type
# 0                     0            1
# 1                     2            2
# 2                     0            1
# ...

# %%
from sklearn.model_selection import train_test_split, cross_val_score

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.3, random_state = 42)

# %% [markdown]
# ## Decision Tree

# %%
# %%time

from sklearn.tree import DecisionTreeRegressor

dt = DecisionTreeRegressor()

dt.fit(X_train,y_train)

y_pred = dt.predict(X_test)
# Out:
# Wall time: 157 ms

# %%
print("Train Accuracy :", dt.score(X_train, y_train)*100)
print("Test Accuracy :", dt.score(X_test, y_test)*100)
# Out:
# Train Accuracy : 100.0
# Test Accuracy : 19.156918405644365

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV

# %%
n_folds = 10
parameters = {
              'max_depth':range(4,40,4),
              'min_samples_leaf':range(50,150,50),
              'min_samples_split':range(50,150,50)}

# %%
# %%time

dtree = DecisionTreeRegressor(random_state=44)

RSCV = RandomizedSearchCV(estimator=dtree, param_distributions=parameters, cv=n_folds)

RSCV.fit(X_train,y_train)

print(RSCV.best_estimator_)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=8, max_features=None,
#                       max_leaf_nodes=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=50,
#                       min_samples_split=50, min_weight_fraction_leaf=0.0,
#                       presort=False, random_state=44, splitter='best')
# Wall time: 1.92 s

# %%
# %%time

dtree = DecisionTreeRegressor(criterion='mse',
                              max_depth=8,
                              min_samples_leaf=50,
                              min_samples_split=50,
                              random_state=44)

dtree.fit(X_train,y_train)

y_pred = dtree.predict(X_test)
# Out:
# Wall time: 20.9 ms

# %%
print("Train Accuracy :", dtree.score(X_train, y_train)*100)
print("Test Accuracy :", dtree.score(X_test, y_test)*100)
# Out:
# Train Accuracy : 61.932735068951516
# Test Accuracy : 58.90611994747914

# %%
# %%time
c = cross_val_score(dtree,X_train,y_train)
print('Variance error :',np.std(c))
print('Bias error :',1-np.mean(c))
# Out:
# Variance error : 0.007633821593096541
# Bias error : 0.4230901272395423
# Wall time: 62.5 ms

# %% [markdown]
# ## Random Forest

# %%
# %%time

from sklearn.ensemble import RandomForestRegressor

rfc = RandomForestRegressor(random_state=32)

rfc.fit(X_train, y_train)

y_pred = rfc.predict(X_test)
# Out:
# Wall time: 286 ms

# %%
print("Train Accuracy :", rfc.score(X_train, y_train)*100)
print("Test Accuracy :", rfc.score(X_test, y_test)*100)
# Out:
# Train Accuracy : 91.32485139639921
# Test Accuracy : 53.44674676924054

# %%
# %%time

param_dist = {'max_depth': range(1,12),
              'bootstrap': [True, False],
              'max_features': ['auto', 'sqrt', 'log2', None]}

cv_rf = RandomizedSearchCV(rfc, cv = 10,param_distributions=param_dist, n_jobs = 3,random_state=32)

cv_rf.fit(X_train,y_train)

cv_rf.best_params_
# Out:
# Wall time: 3.62 s
# {'max_features': None, 'max_depth': 6, 'bootstrap': True}

# %%
# %%time

rfc = RandomForestRegressor(bootstrap=True,
                            max_depth=6,
                            max_features=None,
                            random_state=32)

rfc.fit(X_train,y_train)

y_pred = rfc.predict(X_test)
# Out:
# Wall time: 99.5 ms

# %%
print("Train Accuracy :", rfc.score(X_train, y_train)*100)
print("Test Accuracy :", rfc.score(X_test, y_test)*100)
# Out:
# Train Accuracy : 62.272588326646705
# Test Accuracy : 59.96914352219016

# %%
# %%time
c = cross_val_score(rfc,X_train,y_train)
print('Variance error :',np.std(c))
print('Bias error :',1-np.mean(c))
# Out:
# Variance error : 0.007532328803940888
# Bias error : 0.4141623048747548
# Wall time: 215 ms

# %% [markdown]
# ## XG Boost

# %%
# %%time

from xgboost.sklearn import XGBRegressor

xgbc = XGBRegressor(random_state=32)

xgbc.fit(X_train, y_train)

y_pred = xgbc.predict(X_test)
# Out:
# Wall time: 3.5 s

# %%
print("Train Accuracy :", xgbc.score(X_train, y_train)*100)
print("Test Accuracy :", xgbc.score(X_test, y_test)*100)
# Out:
# Train Accuracy : 86.86139575000503
# Test Accuracy : 52.36005820827552

# %%
# %%time

param_dist = {'n_estimators':range(50,150,50),
              'max_depth':range(1,5)}

xgbc = XGBRegressor(random_state=32)

cv_rf = RandomizedSearchCV(xgbc, cv = 10,param_distributions=param_dist, n_jobs =-1)

cv_rf.fit(X_train,y_train)

cv_rf.best_params_
# Out:
# Wall time: 14.9 s
# {'n_estimators': 50, 'max_depth': 2}

# %%
# %%time

xgbc = XGBRegressor(n_estimators=50,
                             max_depth=2,
                            random_state=32)

xgbc.fit(X_train,y_train)

y_pred = xgbc.predict(X_test)
# Out:
# Wall time: 198 ms

# %%
print("Train Accuracy :", xgbc.score(X_train, y_train)*100)
print("Test Accuracy :", xgbc.score(X_test, y_test)*100)
# Out:
# Train Accuracy : 62.19892699614415
# Test Accuracy : 59.92853078594593

# %%
# %%time
c = cross_val_score(xgbc,X_train,y_train)
print('Variance error :',np.std(c))
print('Bias error :',1-np.mean(c))
# Out:
# Variance error : 0.008971170652839564
# Bias error : 0.409418171529892
# Wall time: 356 ms

# %% [markdown]
# ## Feature Selection

# %%
plt.figure(figsize = (24,10))
sns.heatmap(df.corr(),annot=True)

# %% [markdown]
# Here we can see that item_mrp, order_type are highly correlated with the item_outlet_sales

# %%
from sklearn.linear_model import LinearRegression
from sklearn.feature_selection import RFE

# %%
max_score = 0
n = 0
score_list = []
for i in range(1,len(X.columns)):
    model = LinearRegression()
    rfe = RFE(model, i)
    X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.3, random_state = 0)
    x_train_rfe = rfe.fit_transform(X_train,y_train)
    x_test_rfe = rfe.transform(X_test)
    model.fit(x_train_rfe,y_train)
    score = model.score(x_test_rfe,y_test)
    score_list.append(score)
    if(score>max_score):
        max_score = score
        n = i
print('Optimum no of features: ',n)
print('Score with %d features:  %f '% (n,max_score))
# Out:
# Optimum no of features:  7
# Score with 7 features:  0.509494

# %%
cols = list(X.columns)                                                 # RFE
model = LinearRegression()
#Initializing RFE model
rfe = RFE(model, 7)             
#Transforming data using RFE
x_rfe = rfe.fit_transform(X,y)  
#Fitting the data to model
model.fit(x_rfe,y)              
temp = pd.Series(rfe.support_,index = cols)
selected_features_rfe = temp[temp==True].index
print(selected_features_rfe)
# Out:
# Index(['Item_Fat_Content', 'Item_Visibility', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Size', 'Outlet_Location_Type', 'Outlet_Type'],
#       dtype='object')

# %% [markdown]
# ### New optimal features

# %%
dff=df[['Item_Fat_Content', 'Item_Visibility', 'Item_MRP', 'Outlet_Identifier',
       'Outlet_Size', 'Outlet_Location_Type', 'Outlet_Type']]

# %%
dff.head()
# Out:
#    Item_Fat_Content  Item_Visibility  Item_MRP  Outlet_Identifier  \
# 0                 1         0.016047  249.8092                  9
# 1                 2         0.019278   48.2692                  3
# 2                 1         0.016760  141.6180                  9
# 3                 2         0.000000  182.0950                  0
# 4                 1         0.000000   53.8614                  1
#
#    Outlet_Size  Outlet_Location_Type  Outlet_Type
# 0            1                     0            1
# 1            1                     2            2
# 2            1                     0            1
# 3            1                     2            0
# 4            0                     2            1

# %%
from sklearn.model_selection import train_test_split

# %%
X=dff

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.3, random_state = 42)

# %% [markdown]
# ## Decision Tree Regressor (Feature Selection)

# %%
# %%time

from sklearn.tree import DecisionTreeRegressor

dt = DecisionTreeRegressor()

dt.fit(X_train,y_train)

y_pred = dt.predict(X_test)
# Out:
# Wall time: 48.9 ms

# %%
print("Train Accuracy :", dt.score(X_train, y_train)*100)
print("Test Accuracy :", dt.score(X_test, y_test)*100)
# Out:
# Train Accuracy : 100.0
# Test Accuracy : 22.133476807333427

# %%
n_folds = 10
parameters = {
              'max_depth':range(4,40,4),
              'min_samples_leaf':range(50,150,50),
              'min_samples_split':range(50,150,50)}

# %%
# %%time

dtree = DecisionTreeRegressor(random_state=32)

RSCV = RandomizedSearchCV(estimator=dtree, param_distributions=parameters, cv=n_folds)

RSCV.fit(X_train,y_train)

print(RSCV.best_estimator_)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=28, max_features=None,
#                       max_leaf_nodes=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=100,
#                       min_samples_split=50, min_weight_fraction_leaf=0.0,
#                       presort=False, random_state=32, splitter='best')
# Wall time: 1.4 s

# %%
# %%time

dtree = DecisionTreeRegressor(criterion='mse',
                              max_depth=28,
                              min_samples_leaf=100,
                              min_samples_split=50,
                              random_state=32)

dtree.fit(X_train,y_train)

y_pred = dtree.predict(X_test)
# Out:
# Wall time: 22.1 ms

# %%
print("Train Accuracy :", dtree.score(X_train, y_train)*100)
print("Test Accuracy :", dtree.score(X_test, y_test)*100)
# Out:
# Train Accuracy : 61.118779858887805
# Test Accuracy : 58.91249376284908

# %%
# %%time
c = cross_val_score(dtree,X_train,y_train)
print('Variance error :',np.std(c))
print('Bias error :',1-np.mean(c))
# Out:
# Variance error : 0.00450041155731887
# Bias error : 0.42420640466463866
# Wall time: 46.9 ms

# %% [markdown]
# ## Random Forest Regressor (Feature Selection)

# %%
# %%time

from sklearn.ensemble import RandomForestRegressor

rfc = RandomForestRegressor(random_state=32)

rfc.fit(X_train, y_train)

y_pred = rfc.predict(X_test)
# Out:
# Wall time: 263 ms

# %%
print("Train Accuracy :", rfc.score(X_train, y_train)*100)
print("Test Accuracy :", rfc.score(X_test, y_test)*100)
# Out:
# Train Accuracy : 91.2171029433294
# Test Accuracy : 52.47712641625944

# %%
# %%time

param_dist = {'max_depth': range(1,15),
              'bootstrap': [True, False],
              'max_features': ['auto', 'sqrt', 'log2', None]}

cv_rf = RandomizedSearchCV(rfc, cv = 10,param_distributions=param_dist, n_jobs = 3)

cv_rf.fit(X_train,y_train)

cv_rf.best_params_
# Out:
# Wall time: 3.53 s
# {'max_features': None, 'max_depth': 5, 'bootstrap': False}

# %%
# %%time

rfc = RandomForestRegressor(bootstrap=False,
                
                            max_depth=5,
                            max_features=None,
                            random_state=32)

rfc.fit(X_train,y_train)

y_pred = rfc.predict(X_test)
# Out:
# Wall time: 136 ms

# %%
print("Train Accuracy :", rfc.score(X_train, y_train)*100)
print("Test Accuracy :", rfc.score(X_test, y_test)*100)
# Out:
# Train Accuracy : 60.465280816813326
# Test Accuracy : 59.709067759191804

# %%
# %%time
c = cross_val_score(rfc,X_train,y_train)
print('Variance error :',np.std(c))
print('Bias error :',1-np.mean(c))
# Out:
# Variance error : 0.006448146639011614
# Bias error : 0.4168166031115629
# Wall time: 247 ms

# %% [markdown]
# ## XGB Regressor (Feature Selection)

# %%
# %%time

from xgboost.sklearn import XGBRegressor

xgbc = XGBRegressor(random_state=32)

xgbc.fit(X_train, y_train)

y_pred = xgbc.predict(X_test)
# Out:
# Wall time: 614 ms

# %%
print("Train Accuracy :", xgbc.score(X_train, y_train)*100)
print("Test Accuracy :", xgbc.score(X_test, y_test)*100)
# Out:
# Train Accuracy : 85.0581956223657
# Test Accuracy : 53.25688672951412

# %%
# %%time

param_dist = {'n_estimators':range(50,150,30),
              'max_depth':range(1,5)}

xgbc = XGBRegressor(random_state=44)

cv_rf = RandomizedSearchCV(xgbc, cv = 10,param_distributions=param_dist, n_jobs =-1)

cv_rf.fit(X_train,y_train)

cv_rf.best_params_
# Out:
# Wall time: 17.8 s
# {'n_estimators': 50, 'max_depth': 2}

# %%
# %%time

xgbc = XGBRegressor(n_estimators=50,
                             max_depth=2,
                            random_state=32)

xgbc.fit(X_train,y_train)

y_pred = xgbc.predict(X_test)
# Out:
# Wall time: 169 ms

# %%
print("Train Accuracy :", xgbc.score(X_train, y_train)*100)
print("Test Accuracy :", xgbc.score(X_test, y_test)*100)
# Out:
# Train Accuracy : 62.19967846340867
# Test Accuracy : 59.67363332687554

# %% [markdown]
# So Among all the models Random Forest with Feature selection is performing best as compare to other models.
